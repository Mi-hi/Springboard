# %% [markdown]
# <div style="margin: 0 auto; max-width: 600px;">
#     <div style="background-image: url('https://cdn.pixabay.com/animation/2024/03/06/13/13/13-13-59-799_512.gif');
#                 background-size: cover;
#                 padding: 50px;
#                 font-family: Verdana, sans-serif; /* Changed font family */
#                 border: 4px solid #fff;
#                 border-radius: 20px;
#                 color: #7469B6; /* Text color */
#                 text-align: center;
#                 box-shadow: 0px 8px 15px rgba(0, 0, 0, 0.4);
#                 animation: fadeIn 2s ease-in-out;
#                 height: 450px;"> <!-- Adjusted height -->
#         <h1 style="font-weight: bold; color: #fff;">Unlock the Financial Potential: Discover Credit Card Eligibility </h1>
#         <style>
#             @keyframes fadeIn {
#                 from {
#                     opacity: 0;
#                 }
#                 to {
#                     opacity: 1;
#                 }
#             }
#             h1 {
#                 margin-top: 0;
#                 font-size: 48px;
#                 text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.6);
#             }
#         </style>
#     </div>
# </div>

# %% [markdown]
# ![_38b35af8-74aa-4c82-aef7-6850844f9308 (1).jpg](attachment:c25ec2ea-e21f-48b7-bb78-24a45519e74a.jpg)

# %% [markdown]
# <div style="background-color:#ebebe8; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
#     <h1 style="font-size:24px; font-family:calibri; color:#0A2342;"><b>About Dataset</b></h1>
#     <p style="font-size:20px; font-family:calibri; line-height: 1.5em; text-indent: 20px;">
#         This is the Credit Card Eligibility Dataset.It involves the various factors that determine or Influence the creditcard of a person.
#         From demographic variables like gender and employment status to family numer, family size, Total Income, Education, Occupation and beyond, this dataset comprises of  multifaceted nature of the creditcard assessment.
#         All these factors are necessary to determine the creditworthiness and creditcard eligibility
#     </p>
# </div>

# %% [markdown]
# | Column Name      | Description                                                                 |
# |------------------|-----------------------------------------------------------------------------|
# | ID               | An identifier for each individual (customer).                               |
# | Gender           | The gender of the individual.                                              |
# | Own_car          | A binary feature indicating whether the individual owns a car.              |
# | Own_property     | A binary feature indicating whether the individual owns a property.         |
# | Work_phone       | A binary feature indicating whether the individual has a work phone.        |
# | Phone            | A binary feature indicating whether the individual has a phone.             |
# | Email            | A binary feature indicating whether the individual has provided an email address. |
# | Unemployed       | A binary feature indicating whether the individual is unemployed.           |
# | Num_children     | The number of children the individual has.                                  |
# | Num_family       | The total number of family members.                                         |
# | Account_length   | The length of the individual's account with a bank or financial institution.|
# | Total_income     | The total income of the individual.                                         |
# | Age              | The age of the individual.                                                  |
# | Years_employed   | The number of years the individual has been employed.                       |
# | Income_type      | The type of income (e.g., employed, self-employed, etc.).                   |
# | Education_type   | The education level of the individual.                                      |
# | Family_status    | The family status of the individual.                                        |
# | Housing_type     | The type of housing the individual lives in.                                |
# | Occupation_type  | The type of occupation the individual is engaged in.                        |
# | Target           | The target variable for the classification task, indicating whether the individual is eligible for a credit card or not (e.g., Yes/No, 1/0). |

# %% [markdown]
# <div style="background-color:#ebebe8; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
#     <h1 style="font-size:24px; font-family:calibri; color:#0A2342;"><b>Aims and Objectives</b></h1>
#     <p style="font-size:20px; font-family:calibri; line-height: 1.5em; text-indent: 20px;">
#         As this is the Credit Card Eligibility Dataset. My Aim to take this Dataset is to explore that on what factors a person iis eligible for credit card and to determine the creditworthiness.
#         For This I used the Autoviz Library for automatic visualization that can generate various types of charts based on a given dataset. and then I train the model and determine credit card eligibility based on the facors of the Dataset
#     </p>
# </div>

# %% [markdown]
# <div style="background-color:#ebebe8; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
#     <h1 style="font-size:24px; font-family:calibri; color:#0A2342;"><b>About Author</b></h1>
#     <p style="font-size:20px; font-family:calibri; line-height: 1.5em; text-indent: 20px;">
#         Hi Kagglers! I'm Maria Nadeem and I am a passionate Data Scientist.
#         I'm Exploring and applying various Data Science techniques pationationatly.
#         I'm thrilled to Share my notebooks with kaggle community.
#         In this Notebook, I Explore and took insights about the Data through the AutoViz Library andd then Train the model to determine that on what factors a person is eligible of creditcard
#     </p>
# </div>

# %% [markdown]
# | Name               | Email                                               | LinkedIn                                                  | GitHub                                           | Kaggle                                        |
# |--------------------|-----------------------------------------------------|-----------------------------------------------------------|--------------------------------------------------|-----------------------------------------------|
# | **Maria Nadeem**  | marianadeem755@gmail.com | <a href="https://www.linkedin.com/in/maria-nadeem-4994122aa/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/LinkedIn-%2300A4CC.svg?style=for-the-badge&logo=LinkedIn&logoColor=white" alt="LinkedIn Badge"></a> | <a href="https://github.com/marianadeem755" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/GitHub-%23FF6F61.svg?style=for-the-badge&logo=GitHub&logoColor=white" alt="GitHub Badge"></a> | <a href="https://www.kaggle.com/marianadeem755" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/Kaggle-%238a2be2.svg?style=for-the-badge&logo=Kaggle&logoColor=white" alt="Kaggle Badge"></a> |

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">Import Libraries</p>

# %%
# Import Libraries
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import tensorflow as tf
# Import Train Test split and Grid Search Cv
from sklearn.model_selection import train_test_split, GridSearchCV
# Import LabelEncoder, StandardScaler, PolynomialFeatures
from sklearn.preprocessing import LabelEncoder, StandardScaler, PolynomialFeatures
# Column Transformer
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.ensemble import GradientBoostingClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
# Remove warnings 
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2024-05-27 20:59:59.145032: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-27 20:59:59.145265: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-27 20:59:59.334095: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">🔍Dataset Overview📊</p>

# %%
import pandas as pd
from IPython.display import display, HTML
import io

# Helper function to generate colored horizontal line
def colored_line(color='#ff00ff'):
    return f"<hr style='border: 2px solid {color};'>"

def print_dataset_analysis(df, n_top=5, heading_color='#d35400', line_color='#ff00ff', dash_color='#27ae60'):
    # Styling for the DataFrame display
    table_style = """
    <style>
        table {
            margin: 0 auto;
            border-collapse: collapse;
            color: #333;
        }
        th, td {
            padding: 8px;
            text-align: left;
        }
        tr:nth-child(even) {background-color: #f2f2f2;}
        tr:hover {background-color: #ddd;}
    </style>
    """
    
    # Printing top values
    train_heading = f"<h2 style='color:{heading_color}; text-align:center;'><strong>📋 Top {n_top} Rows of the Dataset</strong></h2>"
    
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(train_heading))
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(table_style + df.head(n_top).to_html(border=0, index=False)))

    # Printing bottom values
    bottom_heading = f"<h2 style='color:{heading_color}; text-align:center;'><strong>🔽 Bottom {n_top} Rows of the Dataset</strong></h2>"
    
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(bottom_heading))
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(table_style + df.tail(n_top).to_html(border=0, index=False)))

    # Printing dataset summary
    summary_heading = f"<h2 style='color:{heading_color}; text-align:center;'><strong>📊Dataset Summary Statistics</strong></h2>"
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(summary_heading))
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(table_style + df.describe().to_html(border=0)))

    # Printing dataset information
    info_heading = f"<h2 style='color:{heading_color}; text-align:center;'><strong>🔍Dataset Information</strong></h2>"
    buffer = io.StringIO()
    df.info(buf=buffer)
    info = buffer.getvalue().replace('\n', '<br>')
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(info_heading))
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(f"<pre>{info}</pre>"))

    # Printing dataset shape
    shape_heading = f"<h2 style='color:{heading_color}; text-align:center;'><strong>📏Dataset Shape</strong></h2>"
    shape_info = f"<p>Rows: {df.shape[0]}, Columns: {df.shape[1]}</p>"
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(shape_heading))
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(shape_info))

    # Printing missing values
    null_heading = f"<h2 style='color:{heading_color}; text-align:center;'><strong>❓ Missing Values in Dataset</strong></h2>"
    null_values = df.isnull().sum().to_frame().reset_index()
    null_values.columns = ['Column', 'Missing Values']
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(null_heading))
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(table_style + null_values.to_html(index=False, border=0)))

    # Printing duplicate rows
    duplicate_heading = f"<h2 style='color:{heading_color}; text-align:center;'><strong>♻️ Duplicate Rows in Dataset</strong></h2>"
    duplicate_count = df.duplicated().sum()
    duplicate_info = f"<p>Number of duplicate rows: {duplicate_count}</p>"
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(duplicate_heading))
    display(HTML(f"<hr style='border: 2px solid {dash_color};'>"))
    display(HTML(duplicate_info))

# Load the DataFrame
df = pd.read_csv("/kaggle/input/credit-card-eligibility-data-determining-factors/dataset.csv")

# Call the function to display the information with the new color scheme
print_dataset_analysis(df, heading_color='#d35400', line_color='#174747', dash_color='#174747')
# Out:
# <hr style='border: 2px solid #174747;'>
# <h2 style='color:#d35400; text-align:center;'><strong>📋 Top 5 Rows of the Dataset</strong></h2>
# <hr style='border: 2px solid #174747;'>
#     <style>
#         table {
#             margin: 0 auto;
#             border-collapse: collapse;
#             color: #333;
#         }
#         th, td {
#             padding: 8px;
#             text-align: left;
#         }
#         tr:nth-child(even) {background-color: #f2f2f2;}
#         tr:hover {background-color: #ddd;}
#     </style>
#     <table class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ID</th>
#       <th>Gender</th>
#       <th>Own_car</th>
#       <th>Own_property</th>
#       <th>Work_phone</th>
#       <th>Phone</th>
#       <th>Email</th>
#       <th>Unemployed</th>
#       <th>Num_children</th>
#       <th>Num_family</th>
#       <th>Account_length</th>
#       <th>Total_income</th>
#       <th>Age</th>
#       <th>Years_employed</th>
# ...

# %%
# !pip install autoviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.3
#     Uninstalling xgboost-2.0.3:
#       Successfully uninstalled xgboost-2.0.3
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
# ...

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">🔍📈 Exploratory Data Analysis with AutoViz 🔥</p>

# %% [markdown]
# ## **Autoviz:**
# - Autoviz is a Python library for automatic visualization that can generate various types of charts based on a given dataset.
#
# - Its goal is to make the data exploration and analysis process more efficient and convenient.
#
# - It eliminates the need of manually writing extensive visualization code.
#
# - `Automation of AutoViz:` AutoViz automates the visualization process, it requires just a single line of code to generate multiple insightful plots.
#
# - `customizing:` AutoViz provides several options for customizing the visualizations, such as changing the chart type, color palette, etc.
#
# - `Installation:` It is installed by just writing this code !pip install autoviz
# - we can import the `AutoViz_Class from the autoviz`
#
# - `Ease of use:` The autoviz library is very helpful for the begineers of Datascience as it provides the detailes Exploration of the Dataset and all the visualization plots which are necessary to take insights about the Data
#
# - `Filename:` Firstly we have to give the name of the file or the dataset on which we have to work.
#
# - `sep:` It represents the File Separator which we can apply in the case when we are giving the filename
#
# - `depVar:` It represents the Target variable of the Dataset.
#
# - `dfte:` It is the name of the pandas Dataframe Plotting chart and we can leave it as empty if we  already gives the filename
#
# - `chart_format:` we can display the charts in the form of 'svg', 'png', 'jpg', 'bokeh', 'server', or 'html'.

# %%
# %matplotlib inline
import os
from autoviz.AutoViz_Class import AutoViz_Class
# Define the AutoViz class
AV = AutoViz_Class()

# Path to the dataset
dataset_path = '/kaggle/input/credit-card-eligibility-data-determining-factors/dataset.csv'

# Generate visualizations
dft = AV.AutoViz(dataset_path)

# Save visualizations
def save_current_figure(fig, filename):
    if not os.path.exists('plots'):
        os.makedirs('plots')
    fig.savefig(os.path.join('plots', filename))

# Example: Save current figure (you might need to iterate over all figures if multiple are generated)
fig = plt.gcf()  # Get the current figure
save_current_figure(fig, 'autoviz_output.png')

# Display saved images
from IPython.display import Image, display

def display_saved_images(image_folder='plots'):
    images = os.listdir(image_folder)
    for image in images:
        display(Image(filename=os.path.join(image_folder, image)))

# Display the saved images
display_saved_images()
# Out:
# Imported v0.1.904. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (9709, 20)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  5
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  8
#     Number of Discrete String Columns =  0
# ...

# %%
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class

# Load your dataset
data = pd.read_csv('/kaggle/input/credit-card-eligibility-data-determining-factors/dataset.csv')

# Select columns of interest
columns_of_interest = ['Gender', 'Unemployed', 'Num_children', 'Num_family', 'Age','Total_income', 'Target']  # Replace with your desired column names

# Subset the data with selected columns
data_subset = data[columns_of_interest]

# Use AutoViz on the subset of data
AV = AutoViz_Class()
AV.AutoViz(data_subset)
# Out:
# Shape of your Data Set loaded: (9709, 7)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  2
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  3
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     7 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">📈 Lets Took insights about the Columns🔍</p>

# %%
# Count the number of males and females using value_counts()
gender_counts = df['Gender'].value_counts()

# Interpret 0 as male and 1 as female
num_males = gender_counts.get(0, 0)  # Get count of males (default to 0 if not present)
num_females = gender_counts.get(1, 0)  # Get count of females (default to 0 if not present)

print("Number of males:", num_males)
print("Number of females:", num_females)
# Out:
# Number of males: 6323
# Number of females: 3386

# %% [markdown]
# ## **Observations:**
# - In this Dataset there are 6323 Males
# - In this Dataset there are 3386 Females are present

# %%
# Count the number of individuals who own a car and who do not
car_owners = df['Own_car'].value_counts()

# Interpret 0 as not owning a car and 1 as owning a car
own_car = car_owners.get(1, 0)  # Get count of individuals who own a car (default to 0 if not present)
dont_own_car = car_owners.get(0, 0)  # Get count of individuals who do not own a car (default to 0 if not present)

print("Number of individuals who own a car:", own_car)
print("Number of individuals who do not own a car:", dont_own_car)
# Out:
# Number of individuals who own a car: 3570
# Number of individuals who do not own a car: 6139

# %% [markdown]
# ## **Observations:**
# - According to this Dataset as there are Number of factors that determine the eligibility criteria of a particular person one of these include own a car
# - 3570 Number of Individuals own a car according to this Dataset.
# - 6139 Number of Individuals donot own a car according to this Dataset.

# %%
# Define eligibility criteria
eligible_criteria = (df['Age'] >= 18) & (df['Own_car'] == 1) & (df['Own_property'] == 1)

# Calculate eligible males and females
eligible_males = len(df[(df['Gender'] == 0) & eligible_criteria])
eligible_females = len(df[(df['Gender'] == 1) & eligible_criteria])

print("Number of eligible males:", eligible_males)
print("Number of eligible females:", eligible_females)
# Out:
# Number of eligible males: 1060
# Number of eligible females: 1315

# %% [markdown]
# ## **Observation:**
# - Based on the number of factors present such as age, own_car and own_property it is determined that 1060 males and 1315 Females are eligible of the credit card

# %%
# Calculate income type distribution for males and females
income_distribution_males = df[df['Gender'] == 0]['Income_type'].value_counts()
income_distribution_females = df[df['Gender'] == 1]['Income_type'].value_counts()

print("Income type distribution for males:")
print(income_distribution_males)

print("\nIncome type distribution for females:")
print(income_distribution_females)
# Out:
# Income type distribution for males:
# Income_type
# Working                 2955
# Commercial associate    1428
# Pensioner               1410
# State servant            528
# Student                    2
# Name: count, dtype: int64
#
# Income type distribution for females:
# Income_type
# Working                 2005
# Commercial associate     884
# Pensioner                302
# State servant            194
# Student                    1
# Name: count, dtype: int64

# %% [markdown]
# ## **Observation:**
# - According to this Dataset 2955 Males are Working, while 1428 are Commercial associate, 1410 are Pensioner, 528 are State servant and 2 are Student
# - While 2005 Female are Working, 884 are Commercial associate,302 are Pensioner,194 are State servant and 1 is Student

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">Encoding Categorical Columns📰</p>

# %%
# Encode categorical variablesa
label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">Split data into Features and Labels📰</p>

# %%
# Split data into features (X) and target variable (y)
X = df.drop(columns=['Target'])
y = df['Target']

# %%
poly = PolynomialFeatures(interaction_only=True, include_bias=False)
X_poly = poly.fit_transform(X)

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">Feature Scaling</p>

# %%
# Feature Scaling
scaler = StandardScaler()
X_poly_scaled = scaler.fit_transform(X_poly)

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">Feature Selection</p>

# %%
# Select the top k features using mutual information
selector = SelectKBest(score_func=mutual_info_classif, k=8)  # Adjust k as needed
X_selected = selector.fit_transform(X_poly_scaled, y)

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">Train Test Split the Data</p>

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">Model Training</p>

# %%
# Define the parameter grid for Gradient Boosting Classifier
param_grid_gb = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_leaf': [1, 2, 3]
}

# Perform GridSearchCV with the parameter grid for Gradient Boosting
grid_search_gb = GridSearchCV(estimator=GradientBoostingClassifier(random_state=42),
                              param_grid=param_grid_gb, cv=5, scoring='accuracy')
grid_search_gb.fit(X_train, y_train)

# Get best parameters and score
best_params_gb = grid_search_gb.best_params_
best_score_gb = grid_search_gb.best_score_

print("Best Parameters for Gradient Boosting:", best_params_gb)
print("Best Score for Gradient Boosting:", best_score_gb)

# Make predictions using the best Gradient Boosting model
best_model_gb = grid_search_gb.best_estimator_
y_pred_train_gb = best_model_gb.predict(X_train)
y_pred_test_gb = best_model_gb.predict(X_test)

# Evaluate the best Gradient Boosting model
train_accuracy_gb = accuracy_score(y_train, y_pred_train_gb)
test_accuracy_gb = accuracy_score(y_test, y_pred_test_gb)
print("Gradient Boosting Model Metrics:")
print("Train Accuracy:", train_accuracy_gb)
print("Test Accuracy:", test_accuracy_gb)
# Confusion matrix
conf_matrix_gb = confusion_matrix(y_test, y_pred_test_gb)
print("Confusion Matrix:\n", conf_matrix_gb)
# Out:
# Best Parameters for Gradient Boosting: {'learning_rate': 0.01, 'max_depth': 3, 'min_samples_leaf': 1, 'n_estimators': 100}
# Best Score for Gradient Boosting: 0.8715076312629435
# Gradient Boosting Model Metrics:
# Train Accuracy: 0.872022659971675
# Test Accuracy: 0.853244078269825
# Confusion Matrix:
#  [[1657    2]
#  [ 283    0]]

# %% [markdown]
# # <p style="background-image: url(https://img.freepik.com/free-vector/technology-background-concept_52683-35555.jpg); font-family: Georgia, serif; font-size: 28px; text-align: center; color: #f5f7fa; padding: 10px; border-radius: 20px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);">Conclusion</p>

# %% [markdown]
# - This is the CreditcardEligibility Dataset.
# - In this Notebook Firstly I took the Complete overview of the Dataset and check whether there are Missing values or Duplicates present in the Dataset
# - I determined that there is no missing values and duplicates present in the Dataset.
# - Then in order to took the detailed Insights about the Datset I Explore the Dataset by selecting the columns which have great importance according to this Dataset using the auto-viz Library.
# - Then in order to take insights about the data I further Explore the Data
# - Then I trained the GradientBoost Model in order to take insights about the creditcard eligibility based on the factors of according to this Dataset

# %% [markdown]
# <div style="margin: 0 auto; max-width: 700px;">
#     <div style="background-image: url('https://i.gifer.com/Wrsu.gif');
#                 background-size: cover;
#                 padding: 50px;
#                 font-family: Verdana, sans-serif; /* Changed font family */
#                 border: 4px solid #fff;
#                 border-radius: 20px;
#                 color: #7469B6; /* Text color */
#                 text-align: center;
#                 box-shadow: 0px 8px 15px rgba(0, 0, 0, 0.4);
#                 animation: fadeIn 2s ease-in-out;
#                 height: 450px;"> <!-- Adjusted height -->
#         <h1 style="font-weight: bold; color: #fff;"></h1>
#         <style>
#             @keyframes fadeIn {
#                 from {
#                     opacity: 0;
#                 }
#                 to {
#                     opacity: 1;
#                 }
#             }
#             h1 {
#                 margin-top: 0;
#                 font-size: 48px;
#                 text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.6);
#             }
#
#             /* Media query for mobile devices */
#             @media only screen and (max-width: 600px) {
#                 div {
#                     max-width: 100%;
#                 }
#                 div > div {
#                     padding: 20px; /* Adjusted padding for mobile */
#                     height: auto; /* Auto height for mobile */
#                 }
#                 h1 {
#                     font-size: 36px; /* Adjusted font size for mobile */
#                 }
#             }
#         </style>
#     </div>
# </div>
